# %% [markdown]
# <a href="https://colab.research.google.com/github/JPP-J/clustering_project/blob/main/example_results_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # cls_kmean.py
# > cls_kmean.py
#
#     Example dataset:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
#     0            7.4              0.70         0.00  ...       0.56      9.4        5
#     1            7.8              0.88         0.00  ...       0.68      9.8        5
#     2            7.8              0.76         0.04  ...       0.65      9.8        5
#     3           11.2              0.28         0.56  ...       0.58      9.8        6
#     4            7.4              0.70         0.00  ...       0.56      9.4        5
#
#     [5 rows x 12 columns]
#     Shape of dataset: (1599, 12)
#     quality count: Counter({5: 681, 6: 638, 7: 199, 4: 53, 8: 18, 3: 10})
#
#     quality count after balance: Counter({5: 199, 6: 199, 7: 199})
#
#     silhouette Coefficients for k= KMeans(n_clusters=2)  is  0.8458953293198952
#     silhouette Coefficients for k= KMeans(n_clusters=3)  is  0.5881030551243598
#     silhouette Coefficients for k= KMeans(n_clusters=4)  is  0.5323245581216214
#     silhouette Coefficients for k= KMeans(n_clusters=5)  is  0.44907449292643137
#     silhouette Coefficients for k= KMeans(n_clusters=6)  is  0.4559409989502998
#     silhouette Coefficients for k= KMeans(n_clusters=7)  is  0.4178350757981856
#     silhouette Coefficients for k= KMeans()  is  0.41382000100228983
#     silhouette Coefficients for k= KMeans(n_clusters=9)  is  0.4016624489425913
#     Optimal K = 2 silhouette Coefficients: 0.8459
#     quality          5    6    7
#     kmeans_cluster
#     0               71   69   55
#     1               82  107  129
#     2               46   23   15
#     quality                 5          6          7
#     kmeans_cluster
#     0               36.410256  35.384615  28.205128
#     1               25.786164  33.647799  40.566038
#     2               54.761905  27.380952  17.857143
#
#     Kmean Clustering:
#     Silhouette Score: 0.5246
#     Adjusted Rand Index: 0.01845
#     Davies-Bouldin Index: 0.6801

# %% [markdown]
# ![{0E66CF3A-722B-435D-87D5-3730940D9FC7}.png](data:image/png;base64,...)

# %% [markdown]
# ![{80062395-CAB2-47E6-9DF7-2DA8011DE766}.png](data:image/png;base64,...)

# %% [markdown]
# ![{57C74C59-3851-4D8C-8B4C-2580CCE0E7B2}.png](data:image/png;base64,...)

# %% [markdown]
# ![{E36638F8-CBA0-488C-B7F4-ACA976B58406}.png](data:image/png;base64,...)

# %% [markdown]
# ![{D14F0477-EFFC-4DAB-AD53-BFF72860B69C}.png](data:image/png;base64,...)

# %% [markdown]
# # cls_DBCSAN.py
#     Example dataset:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
#     0            7.4              0.70         0.00  ...       0.56      9.4        5
#     1            7.8              0.88         0.00  ...       0.68      9.8        5
#     2            7.8              0.76         0.04  ...       0.65      9.8        5
#     3           11.2              0.28         0.56  ...       0.58      9.8        6
#     4            7.4              0.70         0.00  ...       0.56      9.4        5
#
#     [5 rows x 12 columns]
#     Shape of dataset: (1599, 12)
#     quality count: Counter({5: 681, 6: 638, 7: 199, 4: 53, 8: 18, 3: 10})
#
#     quality count after balance: Counter({5: 199, 6: 199, 7: 199})
#
#     best eps: 19, min_pts: 2
#     eps suitable: 19
#     min_sample: 2
#     quality           5    6    7
#     dbscan_cluster
#     0               199  199  197
#     1                 0    0    2
#     quality                 5          6           7
#     dbscan_cluster
#     0               33.445378  33.445378   33.109244
#     1                0.000000   0.000000  100.000000
#
#     DBSCAN:
#     Silhouette Score: 0.8459
#     Adjusted Rand Index: 2.256e-05
#     Davies-Bouldin Index: 0.1283

# %% [markdown]
# ![{F222CB8D-FA32-4A00-B2F7-B03C8E47E232}.png](data:image/png;base64,...)

# %% [markdown]
# ![{F798D330-67E5-4A27-A706-426C390B5F4D}.png](data:image/png;base64,...)

# %% [markdown]
# ![{E26DFE57-E87C-424D-90F7-80AF20F07C63}.png](data:image/png;base64,...)

# %% [markdown]
# ![{0B0C86D0-3D61-4F53-B85F-CE54CD7223A8}.png](data:image/png;base64,...)

# %% [markdown]
# ![{BC5B79AF-FA7E-4B10-848F-E6334FC8BC90}.png](data:image/png;base64,...)

# %% [markdown]
# # cls_agglomerative.py
#
#     Example dataset:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
#     0            7.4              0.70         0.00  ...       0.56      9.4        5
#     1            7.8              0.88         0.00  ...       0.68      9.8        5
#     2            7.8              0.76         0.04  ...       0.65      9.8        5
#     3           11.2              0.28         0.56  ...       0.58      9.8        6
#     4            7.4              0.70         0.00  ...       0.56      9.4        5
#
#     [5 rows x 12 columns]
#     Shape of dataset: (1599, 12)
#     quality count: Counter({5: 681, 6: 638, 7: 199, 4: 53, 8: 18, 3: 10})
#
#     quality count after balance: Counter({5: 199, 6: 199, 7: 199})
#
#     silhouette Coefficients for k= AgglomerativeClustering()  is  0.6313115976864772
#     silhouette Coefficients for k= AgglomerativeClustering(n_clusters=3)  is  0.5215680048605273
#     silhouette Coefficients for k= AgglomerativeClustering(n_clusters=4)  is  0.5316990738742224
#     silhouette Coefficients for k= AgglomerativeClustering(n_clusters=5)  is  0.5306191946456394
#     silhouette Coefficients for k= AgglomerativeClustering(n_clusters=6)  is  0.40580393163680406
#     silhouette Coefficients for k= AgglomerativeClustering(n_clusters=7)  is  0.39420056309882484
#     silhouette Coefficients for k= AgglomerativeClustering(n_clusters=8)  is  0.40146527692460615
#     silhouette Coefficients for k= AgglomerativeClustering(n_clusters=9)  is  0.3493478570199161
#     Optimal K = 2 silhouette Coefficients: 0.6313
#     quality         5    6    7
#     agglo_cluster
#     0              47   24   17
#     1              89  116  135
#     2              63   59   47
#     quality                5          6          7
#     agglo_cluster
#     0              53.409091  27.272727  19.318182
#     1              26.176471  34.117647  39.705882
#     2              37.278107  34.911243  27.810651
#
#     Agglomerative Clustering:
#     Silhouette Score: 0.5216
#     Adjusted Rand Index: 0.01741
#     Davies-Bouldin Index: 0.6931

# %% [markdown]
# ![{EA9564F1-6943-464F-909D-29D7E0BE51F5}.png](data:image/png;base64,...)

# %% [markdown]
# ![{4BF36D3C-F6A9-4CA6-8565-D46981811101}.png](data:image/png;base64,...)

# %% [markdown]
# ![{3D2D1781-0F30-4996-A4E7-40B2431981AB}.png](data:image/png;base64,...)

# %% [markdown]
# ![{F2963219-9C3B-4FA5-B2A6-71589C9D9C0D}.png](data:image/png;base64,...)
